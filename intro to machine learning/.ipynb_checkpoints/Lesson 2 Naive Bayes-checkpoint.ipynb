# %% [markdown]
# # 3. Quiz: Supervised Classification Example

# %% [markdown]
# 1. From an album of tagged photos, recognize someone in a picture
#
# 2. Analysze bank data for weird-looking transactions, and flag those for fraud
#
# 3. Given someone's music choices and a bunch of features of that music(tempo, genre, etc.) recommend a new song
#
# 4. Cluster Udacity students into types based on learning styles.

# %% [markdown]
# **Answer: 1 & 3**
#
# Fraud: do not have an example for them

# %% [markdown]
# # 4. Features and Labels Musical Example

# %% [markdown]
# - Features(input)
#   - intensity
#   - tempo
#   - genre
#   - gender of the voice
#
#
# - Labels(output)
#   - like
#   - don't like

# %% [markdown]
# # 5. Features Visualization Quiz

# %% [markdown]
# Q: Given the information about the songs that Katie likes and doesn't like, in which category does a new song falls into?

# %%
from IPython.display import Image
Image(r"C:\Dev\udacity\intro to machine learning\5_features_visualization_quiz.png")

# %% [markdown]
# # 6. Quiz: Classification By Eye

# %% [markdown]
# Q: Given the information about the songs that Sebastian likes and doesn't like, in which category does a new song falls into?

# %%
Image(r"C:\Dev\udacity\intro to machine learning\6_classification_by_eye.png")

# %% [markdown]
# # 8. Quiz: Speed Scatterplot: Grade and Bumpiness

# %% [markdown]
# Q: In which entry does a flat & smooth(circled case)fall into out of the nine choices?

# %%
Image(r"C:\Dev\udacity\intro to machine learning\8_speed_scatterplot.png")

# %% [markdown]
# # 9. Speed Scatterplot 2

# %% [markdown]
# Q: What about the one in a green circle?
